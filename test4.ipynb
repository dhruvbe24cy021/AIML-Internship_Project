# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv2D,MaxPooling2D,Flatten

# %%
model=keras.Sequential()
model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32,32,3)))
model.add(MaxPooling2D((2, 2)))

model.add(MaxPooling2D((2,2)))
model.add(Conv2D(64, (3,3), strides=(1,1), padding='same', activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))

model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# c:\Users\HP\Desktop\SRM_KT\srm\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# ## YOLO

# %%
from ultralytics import YOLO

# %%
model=YOLO('yolo11n.pt')

# %%
predict_class=[53]
img='./leo3.jpg'
pred=model(img, classes=predict_class, conf=.4)
pred_img=pred[0].plot()

import cv2
cv2.imwrite('image2.jpg', pred_img)
cv2.waitKey(5000)
cv2.destroyAllWindows()
# Out:
# image 1/1 c:\Users\HP\Desktop\SRM_KT\leo3.jpg: 640x480 3 pizzas, 540.6ms
# Speed: 41.6ms preprocess, 540.6ms inference, 26.2ms postprocess per image at shape (1, 3, 640, 480)

# %%
predict_class = [53]   # Pizza class (COCO)

img = "./leo3.jpg"
pred = model(img, classes=predict_class, conf=0.4)

# Count detected pizzas
pizza_count = len(pred[0].boxes)

print("Number of pizzas detected:", pizza_count)

# Draw bounding boxes
pred_img = pred[0].plot()

import cv2

# Write the count on the image
cv2.putText(
    pred_img,
    f"Pizzas: {pizza_count}",
    (20, 40),
    cv2.FONT_HERSHEY_SIMPLEX,
    1,
    (0, 255, 0),
    2
)

cv2.imwrite("image2.jpg", pred_img)

# Display the image
cv2.imshow("Detected Pizzas", pred_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
predict_class=[0,14]
img='./lio2.jpg'
pred=model(img, classes=predict_class, conf=.4)
print(pred[0])
# Out:
# image 1/1 c:\Users\HP\Desktop\SRM_KT\lio2.jpg: 640x640 2 persons, 448.3ms
# Speed: 12.7ms preprocess, 448.3ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %% [markdown]
# ## 9 July

# %%
paragraph = """
Artificial Intelligence is transforming the way people work, learn, and communicate.
It enables computers to perform tasks that normally require human intelligence, such as
understanding language, recognizing images, making decisions, and solving problems.
Python is one of the most popular programming languages for Artificial Intelligence
because of its simplicity and the availability of powerful libraries like NumPy,
Pandas, TensorFlow, and PyTorch. Learning Python and AI can open up opportunities
in data science, machine learning, computer vision, natural language processing,
and robotics.
"""

# Split the paragraph into words
words = paragraph.split()

print("List of words:")
print(words)

print("\nTotal number of words:", len(words))
# Out:
# List of words:
# ['Artificial', 'Intelligence', 'is', 'transforming', 'the', 'way', 'people', 'work,', 'learn,', 'and', 'communicate.', 'It', 'enables', 'computers', 'to', 'perform', 'tasks', 'that', 'normally', 'require', 'human', 'intelligence,', 'such', 'as', 'understanding', 'language,', 'recognizing', 'images,', 'making', 'decisions,', 'and', 'solving', 'problems.', 'Python', 'is', 'one', 'of', 'the', 'most', 'popular', 'programming', 'languages', 'for', 'Artificial', 'Intelligence', 'because', 'of', 'its', 'simplicity', 'and', 'the', 'availability', 'of', 'powerful', 'libraries', 'like', 'NumPy,', 'Pandas,', 'TensorFlow,', 'and', 'PyTorch.', 'Learning', 'Python', 'and', 'AI', 'can', 'open', 'up', 'opportunities', 'in', 'data', 'science,', 'machine', 'learning,', 'computer', 'vision,', 'natural', 'language', 'processing,', 'and', 'robotics.']
#
# Total number of words: 81

# %%
paragraph = """
Artificial Intelligence is transforming the way people work, learn, and communicate.
It enables computers to perform tasks that normally require human intelligence, such as understanding language, recognizing images, making decisions, and solving problems.
Python is one of the most popular programming languages for Artificial Intelligence because of its simplicity and the availability of powerful libraries like NumPy, Pandas, TensorFlow, and PyTorch.
Learning Python and AI can open up opportunities in data science, machine learning, computer vision, natural language processing, and robotics.
"""

# Split the paragraph into sentences
sentences = paragraph.split(".")

print("List of sentences:")
for i, sentence in enumerate(sentences, start=1):
    if sentence.strip():  # Ignore empty strings
        print(f"Sentence {i}: {sentence.strip()}")
# Out:
# List of sentences:
# Sentence 1: Artificial Intelligence is transforming the way people work, learn, and communicate
# Sentence 2: It enables computers to perform tasks that normally require human intelligence, such as understanding language, recognizing images, making decisions, and solving problems
# Sentence 3: Python is one of the most popular programming languages for Artificial Intelligence because of its simplicity and the availability of powerful libraries like NumPy, Pandas, TensorFlow, and PyTorch
# Sentence 4: Learning Python and AI can open up opportunities in data science, machine learning, computer vision, natural language processing, and robotics

# %% [markdown]
# ## NLP

# %%
import nltk

# %%
print(nltk.__version__)
# Out:
# 3.10.0

# %%
import math
from sklearn.feature_extraction.text import TfidfVectorizer
doc=['The cat sat on the mat','The dog played in the park','Cats and dogs are good pets']
tfidf=TfidfVectorizer()
result=tfidf.fit_transform(doc)
print(tfidf.get_feature_names_out())
print(result.toarray())
# Out:
# ['and' 'are' 'cat' 'cats' 'dog' 'dogs' 'good' 'in' 'mat' 'on' 'park'
#  'pets' 'played' 'sat' 'the']
# [[0.         0.         0.39798027 0.         0.         0.
#   0.         0.         0.39798027 0.39798027 0.         0.
#   0.         0.39798027 0.60534851]
#  [0.         0.         0.         0.         0.39798027 0.
#   0.         0.39798027 0.         0.         0.39798027 0.
#   0.39798027 0.         0.60534851]
#  [0.40824829 0.40824829 0.         0.40824829 0.         0.40824829
#   0.40824829 0.         0.         0.         0.         0.40824829
#   0.         0.         0.        ]]

# %%
import math
from sklearn.feature_extraction.text import TfidfVectorizer
doc=['AI is amazing','AI is changing world','Machine learning is amazing']
tfidf=TfidfVectorizer()
result=tfidf.fit_transform(doc)
print(tfidf.get_feature_names_out())
print(result.toarray())
# Out:
# ['ai' 'amazing' 'changing' 'is' 'learning' 'machine' 'world']
# [[0.61980538 0.61980538 0.         0.48133417 0.         0.
#   0.        ]
#  [0.44451431 0.         0.5844829  0.34520502 0.         0.
#   0.5844829 ]
#  [0.         0.44451431 0.         0.34520502 0.5844829  0.5844829
#   0.        ]]

# %%
import nltk

# %%
from nltk.corpus import stopwords

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
text = """There are Characters like periods, exclamation point nd newline char are used to separate the"""
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(text)
filtered_sentence = []
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
text = """There are Characters like periods, exclamation point nd newline char are used to separate the"""
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(text)
filtered_sentence = []
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)

# %%
print(filtered_sentence)
# Out:
# ['There', 'Characters', 'like', 'periods', ',', 'exclamation', 'point', 'nd', 'newline', 'char', 'used', 'separate']

# %%
from nltk.tokenize import word_tokenize
text="""There are Characters like periods, exclamation point nd newline char are used to separate the sentence, But one drawback with split() method, that we can only use one separator at a time, So sentence tokenization """
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['There', 'are', 'Characters', 'like', 'periods', ',', 'exclamation', 'point', 'nd', 'newline', 'char', 'are', 'used', 'to', 'separate', 'the', 'sentence', ',', 'But', 'one', 'drawback', 'with', 'split', '(', ')', 'method', ',', 'that', 'we', 'can', 'only', 'use', 'one', 'separator', 'at', 'a', 'time', ',', 'So', 'sentence', 'tokenization']

# %%
from nltk.tokenize import sent_tokenize
text="""Characters like periods, exclamation point nd newline char are used to separate the sentence, But one drawback with split() method, that we can only use one separator at a time, So sentence tokenization wont be foolproof with split() method."""
sent_tokenize(text)
# Out:
# ['Characters like periods, exclamation point nd newline char are used to separate the sentence, But one drawback with split() method, that we can only use one separator at a time, So sentence tokenization wont be foolproof with split() method.']

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer(language="english")
word="civilization"
stemmer.stem(word)
# Out:
# 'civil'

# %%
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer
porter= PorterStemmer()
lemmatizer = WordNetLemmatizer()
print(f" better\n Stemming: {porter.stem('better')}\n Lemmatization: { lemmatizer.lemmatize('better', pos ='a')}" )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 from nltk.stem import WordNetLemmatizer
# ----> 2 porter= PorterStemmer()
#       3 lemmatizer = WordNetLemmatizer()
#       4 print(f" better\n Stemming: {porter.stem('better')}\n Lemmatization: { lemmatizer.lemmatize('better', pos ='a')}" )
#
# NameError: name 'PorterStemmer' is not defined

# %%
from nltk.stem import
